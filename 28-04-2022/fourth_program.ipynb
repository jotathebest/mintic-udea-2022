# %%
6 = 6
# Out:
#   File "<ipython-input-1-acf0902e7b84>", line 1
#     6 = 6
#          ^
# SyntaxError: can't assign to literal

# %%
# way 1
print(6,7, sep="")

# way 2
six = 6
seven = 7
result = str(six) + str(seven)
print(result)

# way 3
six = 6
seven = 7
print(six, seven, sep="")
# Out:
# 67
# 67
# 67

# %%
# primitives

# string
var = "Jose Garcia"

# int
var = 1

# float
var = 1.2

# -------

# this is not a primitive
# j = √-1
complex_number = 1 + 2j
#complex_number = 1 + j # wrong
complex_number = 1 + 1j

# -------

# %%
# primitive
# Booleans

var_bool = True # 1
var_bool = False # 0

# %%
# wrong
var_bool = TRUE
var_bool = tRuE
print(var_bool)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-bf1694060b35> in <module>()
#       1 # wrong
# ----> 2 var_bool = TRUE
#       3 print(var_bool)
#
# NameError: name 'TRUE' is not defined

# %%
var_bool = True
var_int = 1
result = var_bool + var_int
print(result)
# Out:
# 2

# %%
var_bool = True
var_int = 3.1
result = var_bool + var_int
print(result)
# Out:
# 4.1

# %%
var_bool = True
var_int = 3.1
result = var_bool * var_int
print(result)
# Out:
# 3.1

# %%
var_bool_15 = True # 1
var_str_15 = "Jose"
result = var_bool_15 * var_str_15
print(result)
# Out:
# Jose

# %%
var_bool = False # 0
var_str = "Jose"
result = var_bool * var_str
print(result)

# %%
print("Jose" * 0)

# %%
# Bonus types

# List

my_list = [True, 1, 2.3, "Jose"]
print(my_list)

print(my_list[0])
print(my_list[2])
# Out:
# [True, 1, 2.3, 'Jose']
# True
# 2.3

# %%
my_list_1 = [True, 5, 2.3, "Jose"]
my_list_2 = [False, 4, 56, 4, "Garcia", True, True]

val_1 = my_list_1[1]
val_2 = my_list_2[4]
print(val_1 * val_2)
print(my_list_1[1] * my_list_2[4])
# Out:
# GarciaGarciaGarciaGarciaGarcia
# GarciaGarciaGarciaGarciaGarcia

# %%
my_list_1 = [True, -1, -4, -5.6]
print(my_list_1[3] * 5)

my_list_2 = [-3]
print(my_list_2[0])
# Out:
# -28.0
# -3

# %%
another_list_1 = [1, 2, 3]
another_list_2 = [4, 5, 6]
result = another_list_1 * another_list_2
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-e0c1731fc4ef> in <module>()
#       1 another_list_1 = [1, 2, 3]
#       2 another_list_2 = [4, 5, 6]
# ----> 3 result = another_list_1 * another_list_2
#       4 print(result)
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
another_list_3 = [1, 2, 3]
multiplier = 2000
result = another_list_3 * multiplier
print(result)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3
# ...

# %%
another_list_1 = [1, 2, 3]
another_list_2 = [4, 5, 6]
result = another_list_1[1] * another_list_2[1]
print(result)
# Out:
# 10

# %%
another_list_1 = [1, 2, 3]
result = sum(another_list_1)
print(result)
# Out:
# 6

# %%
another_list_6 = [5.5, 6.5, 8]
print(another_list_6[-1])
# Out:
# 8

# %%
# Set
pepito = {True, -1, 3, 5, 1, "Jose"}
print(pepito)
# Out:
# {True, 3, 5, 'Jose', -1}

# %%
# Set
pepito = {True, -1, 3, 5, 1, "Jose"}
pepito_list = list(pepito)
print(pepito_list[0])
# Out:
# True

# %%
set_1 = {"Jose", "Garcia"}
set_2 = {"Jose", "Reyes", "Velasquez"}
difference = set_1.difference(set_2)
print(difference)

difference_2 = set_2.difference(set_1)
print(difference_2)

union = set_1.union(set_2)
union_2 = set_2.union(set_1)
print(union)

print(set_2 - set_1)
# Out:
# {'Garcia'}
# {'Reyes', 'Velasquez'}
# {'Reyes', 'Velasquez', 'Jose', 'Garcia'}
# {'Reyes', 'Velasquez'}

# %%
my_list = [1, 1, 1, 2]
my_set = set(my_list)
result = list(my_set)
print(result)
# Out:
# [1, 2]

# %%
# tuple
my_tuple = (1, 2, 3)
print(my_tuple)
# Out:
# (1, 2, 3)

# %%
print(my_tuple[0])
# Out:
# 1

# %%
my_tuple = (1,2,3)
result = my_tuple * 2
print(result)
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)

print(my_list)
my_list[0] = "jose"
print(my_list)

print(my_tuple)
my_tuple[0] = "jose"
print(my_tuple)
# Out:
# [1, 2, 3]
# ['jose', 2, 3]
# (1, 2, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-b03881ece75a> in <module>()
#       7
#       8 print(my_tuple)
# ----> 9 my_tuple[0] = "jose"
#      10 print(my_tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# list is a mutable type
# tuple is a unmutable type

# %%
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)
result = my_list * my_tuple
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-0ddb7e721557> in <module>()
#       1 my_list = [1, 2, 3]
#       2 my_tuple = (1, 2, 3)
# ----> 3 result = my_list * my_tuple
#       4 print(result)
#
# TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
my_tuple_1 = (1, 2, 3)
my_tuple_2 = (4, 5, 6)
result = my_tuple_1 + my_tuple_2
print(result)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
my_list = [1, 2, "jose"]
my_list.pop(2)
print(my_list)
my_list.append("new_value")
print(my_list)
# Out:
# [1, 2]
# [1, 2, 'new_value']
